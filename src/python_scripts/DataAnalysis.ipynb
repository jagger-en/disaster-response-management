# %%
import pandas as pd
import helperFunc
pd.set_option('display.max_rows', 500)
df = pd.DataFrame(helperFunc.access_endpoint("/summaries/all"))
df_small = df[['firstName', 'lastName', 'jobTitleName', 'missionName', 'teamName']]
df_small.head(500)
# Out:
#                            firstName  lastName  jobTitleName  missionName  \
# -30.49294855698768               NaN       NaN           NaN          NaN
# -30.502830904544094              NaN       NaN           NaN          NaN
# 152.89349913597104               NaN       NaN           NaN          NaN
# 152.9108476638794                NaN       NaN           NaN          NaN
# Aaron                           15.0       NaN           NaN          NaN
# Adams                            NaN      15.0           NaN          NaN
# Adens                            NaN      19.0           NaN          NaN
# Alpha838                         NaN       NaN           NaN          NaN
# Andre                           40.0       NaN           NaN          NaN
# Annette                         51.0       NaN           NaN          NaN
# Anthony                         51.0       NaN           NaN          NaN
# Arnold                          15.0       NaN           NaN          NaN
# ...
